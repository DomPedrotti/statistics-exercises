# %%
###We're using python for experimental probabilities, not theoretical

# %%
import numpy as np
import random

# %%
np.random.choice(['a','b','c'], (3,10))
# Out:
# array([['c', 'a', 'b', 'c', 'c', 'c', 'b', 'c', 'a', 'b'],
#        ['a', 'b', 'a', 'b', 'b', 'a', 'a', 'b', 'a', 'a'],
#        ['b', 'a', 'c', 'b', 'a', 'b', 'a', 'b', 'a', 'b']], dtype='<U1')

# %%
np.random.uniform(10,20, (4,4))
# Out:
# array([[15.37700973, 18.25562961, 14.52292735, 18.02576077],
#        [18.12105436, 12.30051676, 15.30105932, 11.64461578],
#        [14.34187408, 17.78480189, 13.54870785, 10.503108  ],
#        [19.40450649, 10.61318257, 12.24545063, 17.56137074]])

# %%
np.random.random((4,4))
# Out:
# array([[0.12026679, 0.49563786, 0.41262102, 0.01243411],
#        [0.00253867, 0.60346182, 0.71558314, 0.70120326],
#        [0.13368053, 0.16083594, 0.06164974, 0.53994593],
#        [0.32036263, 0.83102006, 0.31942029, 0.49046522]])

# %%
np.random.randn(10,3)
# Out:
# array([[ 4.90091647e-01, -4.88780897e-01,  3.29454650e-01],
#        [-7.88538317e-01,  9.41675690e-01, -6.65994188e-01],
#        [-4.64158313e-01, -3.93411818e-01, -1.88254247e+00],
#        [ 8.73300131e-01, -5.51575652e-01,  1.05066142e-03],
#        [ 1.85300126e+00,  4.52657044e-01, -6.43231329e-01],
#        [ 5.51262712e-01,  6.67572376e-01, -6.11147049e-01],
#        [-7.56541796e-01, -2.93277231e-01, -1.21609517e-01],
#        [ 1.75709868e-01, -1.16310313e+00, -8.20534723e-01],
#        [ 1.56051053e-01,  8.06533903e-01,  1.11338669e+00],
#        [ 1.78000356e-01, -5.93821568e-01, -1.37076773e+00]])

# %%
np.random.normal(10,3,(10,3))
# Out:
# array([[ 9.34888196,  6.36556732, 10.79218945],
#        [10.03973983,  7.77351669, 10.84261866],
#        [11.93292858,  9.41287442, 11.08683848],
#        [13.3397092 , 16.63576963,  8.69480164],
#        [11.14372   , 13.89808289,  9.04164053],
#        [ 7.44092729, 11.48831233,  9.3669639 ],
#        [ 7.91966325, 13.79014533, 10.96381168],
#        [ 9.32305974,  9.56110932, 12.12674639],
#        [17.00562198, 11.24804132,  8.35386543],
#        [11.84723806,  9.24010708,  6.08700085]])

# %%
n_trials = nrows = 10_000
n_dice = ncols = 3

rolls = np.random.choice([1,2,3,4,5,6], n_trials * n_dice).reshape(nrows, ncols)
rolls
# Out:
# array([[3, 3, 1],
#        [4, 6, 1],
#        [4, 4, 5],
#        ...,
#        [4, 3, 5],
#        [1, 6, 3],
#        [5, 3, 3]])

# %%
rolls.sum(axis = 1)
# Out:
# array([ 7, 11, 13, ..., 12, 10, 11])

# %%
rolls.sum(axis = 1) > 12
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
sum(rolls.sum(axis = 1) > 12)
# Out:
# 2600

# %%
(rolls.sum(axis = 1) > 12).mean()
# Out:
# 0.26

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.hist(rolls.sum(axis = 1))
# Out:
# <img src="data:image/png;base64,..." width="604">
# (array([ 174.,  297., 1125.,  971., 2383., 1287., 2127.,  708.,  745.,
#          183.]),
#  array([ 3. ,  4.5,  6. ,  7.5,  9. , 10.5, 12. , 13.5, 15. , 16.5, 18. ]),
#  <a list of 10 Patch objects>)

# %%
p_win = (rolls.sum(axis = 1) > 12).mean()

# %%
amount_we_win = 15
cost = 5
expected_winnings = p_win * amount_we_win
profit = expected_winnings - cost
profit
# Out:
# -1.0999999999999996
